# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 5016.7/8062.4 GB disk)

# %% [markdown]
# # **Rice Pest and detection - YOLOv8**
#
# The dataset used was IP102 dataset, in which 12 classes were used for trainig.
#
# To increase the size of the dataset few image augmentation technique was used.The following are the augmentation techniques used:
#
# - Horizontal Flip
# - Vertical Flip
# - Linear Contrast
# - Multiply
#
# Total no of images = 7633 The dataset was divided into 70-30 for training and testing respectively.
#
# No of images for training = 5357
#
# No of images for testing = 2296

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # **Transfer learning with yolov8n.pt**

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/rice-pest/data.yaml epochs=150 imgsz=416 plots=True

# %% [markdown]
# # **Transfer learning with yolov8s.pt**

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/input/rice-pest/data.yaml epochs=150 imgsz=416 plots=True

# %% [markdown]
# # **Transfer learning with yolov8m.pt**

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/kaggle/input/rice-pest/data.yaml epochs=150 imgsz=416 plots=True
# Out:
# ...
# 100%|██████████████████████████████████████| 49.7M/49.7M [00:01<00:00, 49.9MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %% [markdown]
# # **Transfer learning with yolov8l.pt**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/kaggle/input/rice-pest/data.yaml epochs=150 imgsz=416 plots=True
# Out:
# ...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 157MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...
